# %%
import pandas as pd

hafeez = ['Hafeez', 19]
aslan = ['Aslan', 21]
kareem = ['Kareem', 18]

data_frame = pd.DataFrame([hafeez, aslan, kareem], columns=['Name', 'Age'])
print(data_frame)
# Out:
#      Name  Age
# 0  Hafeez   19
# 1   Aslan   21
# 2  Kareem   18
